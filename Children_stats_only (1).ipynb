# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd = pd.read_excel('C:/Users/Nikhil/Downloads/children_stats_only.xlsx')

# %%
cd
# Out:
#     Unnamed: 0  Unnamed: 0.1                            Name   Age  Gender  \
# 0           32            32                    arya tara rai     7      f
# 1           66            66               sriya  sreenivasan     7      f
# 2          109           109                  shitanshu verma     5      m
# 3          151           151                        rizanizar    10      f
# 4          164           164                      iffa ahmed     10      f
# 5          173           173                  sheetal kumari      6      f
# 6          190           190                         devasree     8      f
# 7          223           223               amrit t krishnadas    11      m
# 8          282           283                sriya sreenivasan     7      f
# 9          373           374                   sabrina gurung    11      f
# 10         512           514            annette adarsh kurias     8      f
# ...

# %%
cd.columns[0:40]
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Name ', 'Age ', 'Gender', 'Place ',
#        'Height ', 'Weight ', 'BMI', 'Occupation', 'Marital Status',
#        'Ethinicity ', 'Diet', 'Allergy', 'Alcohol intake', 'Smoking Cigars',
#        'Addiction(Others if any)', 'Preffered cooking oil', 'Salt', 'Sweet',
#        'Blood pressure', 'Hb', 'ESR', 'Fasting blood sugar ', 'HbA1C',
#        'Total Cholesterol', 'HDL', 'LDL', 'Triglyceride', 'TSH', 'Uric Acid',
#        'Urea', 'Creatinine', 'SGOT', 'SGPT', 'Prescritpion', 'Lab-Report',
#        'X-ray', 'Skin allergies ',
#        '1.On a scale of 1-5, how much do you feel irritable if there is a delay in food or if a meal is missed?'],
#       dtype='object')

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Columns: 127 entries, Unnamed: 0 to Kind of exercises you prefer(yoga/weight
# training/Strength Training/Functional
# Movements/cardio/cross training etc)
# dtypes: float64(14), int64(6), object(107)
# memory usage: 22.9+ KB

# %%
cd.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1       Age      Height     Weight         BMI  \
# count    23.000000     23.000000  23.000000   23.000000  23.000000  23.000000
# mean    487.391304    920.304348   8.130435  142.826087  44.130435  21.347826
# std     320.325791   1209.131598   1.984127   21.278782  20.789649   3.039269
# min      32.000000     32.000000   5.000000  111.000000  21.000000  14.000000
# 25%     181.500000    181.500000   7.000000  122.000000  26.000000  20.500000
# 50%     521.000000    523.000000   8.000000  140.000000  35.000000  23.000000
# 75%     698.500000    702.000000  10.000000  170.000000  70.000000  23.000000
# max    1030.000000   4072.000000  11.000000  170.000000  70.000000  24.000000
#
#        1.On a scale of 1-5, how much do you feel irritable if there is a delay in food or if a meal is missed?  \
# count                                          23.000000
# mean                                            3.608696
# ...

# %%
cd.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                 0
# Unnamed: 0.1                                                                                                               0
# Name                                                                                                                       0
# Age                                                                                                                        0
# Gender                                                                                                                     0
#                                                                                                                           ..
# Participating category(ies)                                                                                               23
# ...

# %%
cd['1.On a scale of 1-5, how much do you feel irritable if there is a delay in food or if a meal is missed?'].value_counts()
# Out:
# 5.0    15
# 1.0     8
# Name: 1.On a scale of 1-5, how much do you feel irritable if there is a delay in food or if a meal is missed?, dtype: int64

# %%
cd['MENOPAUSAL FEMALES ONLY'].isnull().sum()
# Out:
# 23

# %%
cd.isnull().sum()[120:130]
# Out:
# What kind of sports                                                                                                       23
# (IF ATHLETE)                                                                                                              22
# Participating category(ies)                                                                                               23
# (IF FITNESS ENTHUSIAST)                                                                                                    0
# Do you exercise regularly                                                                                                  0
#  How many hours per week                                                                                                   0
# Kind of exercises you prefer(yoga/weight\ntraining/Strength Training/Functional \nMovements/cardio/cross training etc)    23
# dtype: int64

# %%
cd['2. On a scale of 1-5, how much fatigue do you feel after having your meals?'].value_counts()
# Out:
# 1.0    23
# Name: 2. On a scale of 1-5, how much fatigue do you feel after having your meals?, dtype: int64

# %%
cd.iloc[:,120:130]
# Out:
#     What kind of sports (IF ATHLETE)  Participating category(ies)  \
# 0                   NaN          NaN                          NaN
# 1                   NaN          NaN                          NaN
# 2                   NaN          NaN                          NaN
# 3                   NaN          NaN                          NaN
# 4                   NaN          NaN                          NaN
# 5                   NaN          NaN                          NaN
# 6                   NaN          NaN                          NaN
# 7                   NaN          NaN                          NaN
# 8                   NaN          NaN                          NaN
# 9                   NaN          NaN                          NaN
# 10                  NaN          NaN                          NaN
# 11                  NaN          NaN                          NaN
# 12                  NaN          NaN                          NaN
# ...

# %%
cd
# Out:
#     Unnamed: 0  Unnamed: 0.1                            Name   Age  Gender  \
# 0           32            32                    arya tara rai     7      f
# 1           66            66               sriya  sreenivasan     7      f
# 2          109           109                  shitanshu verma     5      m
# 3          151           151                        rizanizar    10      f
# 4          164           164                      iffa ahmed     10      f
# 5          173           173                  sheetal kumari      6      f
# 6          190           190                         devasree     8      f
# 7          223           223               amrit t krishnadas    11      m
# 8          282           283                sriya sreenivasan     7      f
# 9          373           374                   sabrina gurung    11      f
# 10         512           514            annette adarsh kurias     8      f
# ...

# %%
cd.iloc[:,3].value_counts()
# Out:
# 10    5
# 8     5
# 7     4
# 5     3
# 11    3
# 6     2
# 9     1
# Name: Age , dtype: int64

# %% [markdown]
# # plot countplot of Age and seperate with gender

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd.iloc[:,3],hue=cd['Gender'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from the visulization we can easily find out the how many number of male and female with respective age in dataset

# %% [markdown]
# # plot countplot for occupation and with gender

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd['Occupation'], hue=cd['Gender'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from the visulization we can easily find out the how many number of male and female with respective Occupation in dataset

# %% [markdown]
# # plot countplot for occupation and with Diet

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd['Occupation'], hue=cd['Diet'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from the visulization we can easily find out the how many number of different diets of different occupation.

# %% [markdown]
# # plot counplot for diet and separate with gender

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd['Diet'],hue=cd['Gender'],)
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from the visulization we can easily find out the how many number of different male and female for different occupation

# %%
cd['Preffered cooking oil'].value_counts()
# Out:
# nil                                                  6
# coconut oil                                          5
# mustard oil                                          3
# rice bran oil                                        2
# sunflower oil,mustard oil                            1
# mustard oil                                          1
# coconut oil ,olive oil and sunflower oil (rarely)    1
# coconut oil                                          1
# rice bran oil                                        1
# refined oil                                          1
# peanut oil                                           1
# Name: Preffered cooking oil, dtype: int64

# %%
cd['Total Cholesterol'].value_counts()
# Out:
# normal    15
# low        7
# high       1
# Name: Total Cholesterol, dtype: int64

# %% [markdown]
# # plot countplot for cholesterol and seperate with preffered cooking oil

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd['Total Cholesterol'], hue=cd['Preffered cooking oil'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from the visulization we can easily find out the how many number of different Preffered cooking oil for different Cholestrol

# %%
cd['Salt'].value_counts()
# Out:
# craves            15
# not interested     6
# prefers            2
# Name: Salt, dtype: int64

# %%
cd['Sweet'].value_counts()
# Out:
# craves            15
# not interested     7
# prefers            1
# Name: Sweet, dtype: int64

# %%
cd['Blood pressure'].value_counts()
# Out:
# normal    15
# low        8
# Name: Blood pressure, dtype: int64

# %%
cd.iloc[:,23].value_counts()
# Out:
# normal    15
# low        7
# high       1
# Name: Fasting blood sugar , dtype: int64

# %% [markdown]
# # plot countplot and sepearte with sweet

# %%
plt.figure(figsize=(10,8))
sns.countplot(cd.iloc[:,23], hue=cd['Gender'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from visulization easily find out the which gender has high Fasting blood sugar

# %%
cd['(IF SPORT PERSON)'].value_counts()
# Out:
# yes    23
# Name: (IF SPORT PERSON), dtype: int64

# %%
cd
# Out:
#     Unnamed: 0  Unnamed: 0.1                            Name   Age  Gender  \
# 0           32            32                    arya tara rai     7      f
# 1           66            66               sriya  sreenivasan     7      f
# 2          109           109                  shitanshu verma     5      m
# 3          151           151                        rizanizar    10      f
# 4          164           164                      iffa ahmed     10      f
# 5          173           173                  sheetal kumari      6      f
# 6          190           190                         devasree     8      f
# 7          223           223               amrit t krishnadas    11      m
# 8          282           283                sriya sreenivasan     7      f
# 9          373           374                   sabrina gurung    11      f
# 10         512           514            annette adarsh kurias     8      f
# ...

# %%
cd['Kind of exercises you prefer(yoga/weight\ntraining/Strength Training/Functional \nMovements/cardio/cross training etc)']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# Name: Kind of exercises you prefer(yoga/weight\ntraining/Strength Training/Functional \nMovements/cardio/cross training etc), dtype: float64

# %%
cd.iloc[:,6].value_counts()
# Out:
# 170    7
# 122    3
# 121    2
# 140    2
# 128    2
# 130    1
# 149    1
# 111    1
# 136    1
# 145    1
# 160    1
# 120    1
# Name: Height , dtype: int64

# %%
cd.iloc[:,7].value_counts()
# Out:
# 70    8
# 25    4
# 35    2
# 27    2
# 28    2
# 38    1
# 34    1
# 22    1
# 21    1
# 60    1
# Name: Weight , dtype: int64

# %%
cd.iloc[:,124].value_counts()
# Out:
# yes    23
# Name: Do you exercise regularly, dtype: int64

# %%
c = cd.iloc[:,3:8].corr()

# %%
c
# Out:
#              Age    Height    Weight
# Age      1.000000 -0.226604 -0.353054
# Height  -0.226604  1.000000  0.879905
# Weight  -0.353054  0.879905  1.000000

# %% [markdown]
# # heatmap between Age,Height,Weight

# %%
plt.figure(figsize=(10,8))
sns.heatmap(c)
plt.show()

# %% [markdown]
# #Visulization shows the how the Age, Height, Weight correlated with each other

# %%
d = cd.iloc[:,3:8]

# %%
d.drop(columns=['Gender','Place '],inplace=True)

# %%
d
# Out:
#     Age   Height   Weight
# 0      7      170       70
# 1      7      122       35
# 2      5      170       70
# 3     10      130       25
# 4     10      149       38
# 5      6      121       25
# 6      8      111       27
# 7     11      136       25
# 8      7      122       35
# 9     11      170       70
# 10     8      140       70
# 11     8      128       27
# 12     5      170       70
# 13    10      145       34
# 14    10      122       28
# 15     5      170       70
# 16     9      140       22
# 17     6      170       70
# 18     7      128       21
# 19    11      160       60
# 20     8      170       70
# 21     8      120       25
# 22    10      121       28

# %% [markdown]
# # Boxplot for age

# %%
plt.figure(figsize=(10,8))
sns.boxplot(cd['Age '])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #from visulization get the overall distribution of age values

# %% [markdown]
# # Countplot for Height and with seperate Gender

# %%
plt.figure(figsize=(15,8))
sns.countplot(cd['Height '], hue=cd['Gender'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #Visulization used to determine the gender height distribution

# %% [markdown]
# # Countplot for Weight and seperate with gender

# %%
plt.figure(figsize=(15,8))
sns.countplot(cd['Weight '], hue=cd['Gender'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #Visulization used to determine the gender weight distribution

# %%
cd.iloc[:,50:60]
# Out:
#    4. How much time do you sleep in a day  \
# 0                    d. more than 8 hours
# 1                    d. more than 8 hours
# 2                            c. 6-8 hours
# 3                    a. less than 5 hours
# 4                    a. less than 5 hours
# 5                    d. more than 8 hours
# 6                    d. more than 8 hours
# 7                    d. more than 8 hours
# 8                            c. 6-8 hours
# 9                            c. 6-8 hours
# 10                                    NaN
# 11                                    NaN
# 12                           c. 6-8 hours
# 13                           c. 6-8 hours
# 14                           c. 6-8 hours
# 15                                    NaN
# 16                                    NaN
# 17                           c. 6-8 hours
# 18                           c. 6-8 hours
# 19                          b. 5 -6 hours
# 20                           c. 6-8 hours
# ...

# %%
cd['4. How much time do you sleep in a day'].value_counts()
# Out:
# c. 6-8 hours            9
# d. more than 8 hours    5
# a. less than 5 hours    3
# b. 5 -6 hours           2
# Name: 4. How much time do you sleep in a day, dtype: int64

# %%
cd.groupby('4. How much time do you sleep in a day')['Age '].value_counts()
# Out:
# 4. How much time do you sleep in a day  Age
# a. less than 5 hours                    10      2
#                                         8       1
# b. 5 -6 hours                           10      1
#                                         11      1
# c. 6-8 hours                            5       2
#                                         7       2
#                                         10      2
#                                         6       1
#                                         8       1
#                                         11      1
# d. more than 8 hours                    7       2
#                                         6       1
#                                         8       1
#                                         11      1
# Name: Age , dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np

# %%
x = 30
np.tan(x)
# Out:
# -6.405331196646276

# %%
x+10
# Out:
# 40

# %%
x-5
# Out:
# 25

# %%
len('asch')
# Out:
# 4

# %%
y = 'asch'

# %%
y.upper()
# Out:
# 'ASCH'

# %%
x = (1,2,3,4,5,6)

# %%
type(x)
# Out:
# tuple

# %%
x = [1,2,3,4,5]

# %%
type(x)
# Out:
# list

# %%
z = np.array([1,2,3,4,5])

# %%
z.shape
# Out:
# (5,)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler
import scipy.stats as sc
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, r2_score
from sklearn.cluster import KMeans
import sqlite3 as sq

# %%
ca = pd.read_csv('C:/Users/Nikhil/AppData/Local/Temp/Temp1_car_price_prediction.csv.zip/car_price_prediction.csv')

# %%
ca
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
ca.shape
# Out:
# (19237, 18)

# %%
ca.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
ca.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
ca.notnull().sum()
# Out:
# ID                  19237
# Price               19237
# Levy                19237
# Manufacturer        19237
# Model               19237
# Prod. year          19237
# Category            19237
# Leather interior    19237
# Fuel type           19237
# Engine volume       19237
# Mileage             19237
# Cylinders           19237
# Gear box type       19237
# Drive wheels        19237
# Doors               19237
# Wheel               19237
# Color               19237
# Airbags             19237
# dtype: int64

# %%
ca.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
ca['Mileage'].str.split(' ').str[0]
# Out:
# 0        186005
# 1        192000
# 2        200000
# 3        168966
# 4         91901
#           ...
# 19232    300000
# 19233    161600
# 19234    116365
# 19235     51258
# 19236    186923
# Name: Mileage, Length: 19237, dtype: object

# %%
ca['Mileage'] = ca['Mileage'].str.split(' ').str[0]

# %%
ca
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
ca.iloc[:,:]['Mileage'].max()
# Out:
# '999999999'

# %%
ca[ca['Mileage']==ca['Mileage'].max()]
# Out:
#              ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 5456   45790905  12544     -       NISSAN  X-Terra        2004       Jeep
# 10667  45758137   6476     -       NISSAN     Note        2008  Hatchback
# 12591  45781683   2600  1529         OPEL   Vectra        1995      Sedan
# 12904  45782854   4077     -   VOLKSWAGEN     Golf        1997  Hatchback
# 16586  45779768  14113     -          BMW      328        2007      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 5456                No       CNG           3.3  999999999        6.0
# 10667               No       CNG           1.5  999999999        4.0
# 12591               No       CNG           1.8  999999999        4.0
# 12904               No       CNG           1.8  999999999        4.0
# 16586              Yes    Petrol             3  999999999        6.0
#
#       Gear box type Drive wheels   Doors             Wheel          Color  \
# ...

# %%
ca.groupby('Fuel type')['Category'].count().sort_values(ascending=False).plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='Fuel type'>

# %%
ca['Prod. year'].sort_values(ascending=True)
# Out:
# 10265    1939
# 15613    1939
# 11219    1939
# 6607     1943
# 12849    1947
#          ...
# 4049     2020
# 11920    2020
# 13016    2020
# 13334    2020
# 10382    2020
# Name: Prod. year, Length: 19237, dtype: int64

# %%
b = ca[ca['Prod. year']==2020]

# %%
b
# Out:
#              ID   Price  Levy   Manufacturer           Model  Prod. year  \
# 956    45773920   12074  1273            KIA        Sportage        2020
# 979    45766531   39829  1323         TOYOTA           Camry        2020
# 1225   45795524  627220     -  MERCEDES-BENZ  G 65 AMG 63AMG        2020
# 1626   45732087   96915  1076        HYUNDAI        Santa FE        2020
# 2133   45806498    8311  1273            KIA        Sportage        2020
# 3641   45732084   96749  1076        HYUNDAI        Santa FE        2020
# 4049   45769092   31675  1817         TOYOTA          Tacoma        2020
# 4077   45802851   90919  1076        HYUNDAI        Santa FE        2020
# 4590   45732088   88438  1076        HYUNDAI        Santa FE        2020
# 5291   45802845   81445  1174        HYUNDAI        Santa FE        2020
# 5735   45768361   15210  1076        HYUNDAI         Elantra        2020
# 6421   45792175    6899   460         TOYOTA         Corolla        2020
# ...

# %%
b.shape
# Out:
# (47, 18)

# %%
b.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 956 to 19180
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                47 non-null     int64
#  1   Price             47 non-null     int64
#  2   Levy              47 non-null     object
#  3   Manufacturer      47 non-null     object
#  4   Model             47 non-null     object
#  5   Prod. year        47 non-null     int64
#  6   Category          47 non-null     object
#  7   Leather interior  47 non-null     object
#  8   Fuel type         47 non-null     object
#  9   Engine volume     47 non-null     object
#  10  Mileage           47 non-null     object
#  11  Cylinders         47 non-null     float64
#  12  Gear box type     47 non-null     object
#  13  Drive wheels      47 non-null     object
#  14  Doors             47 non-null     object
#  15  Wheel             47 non-null     object
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(b['Fuel type'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.countplot(b['Gear box type'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.countplot(b['Airbags'])
plt.show()
# Out:
# C:\Users\Nikhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
b['Price'].describe()
# Out:
# count        47.000000
# mean      63006.106383
# std       91748.310488
# min           3.000000
# 25%       13642.000000
# 50%       61781.000000
# 75%       88438.000000
# max      627220.000000
# Name: Price, dtype: float64

# %%
b.describe()
# Out:
#                  ID          Price  Prod. year  Cylinders    Airbags
# count  4.700000e+01      47.000000        47.0  47.000000  47.000000
# mean   4.573359e+07   63006.106383      2020.0   4.489362   7.617021
# std    2.280244e+05   91748.310488         0.0   1.516179   4.245474
# min    4.467634e+07       3.000000      2020.0   1.000000   0.000000
# 25%    4.576476e+07   13642.000000      2020.0   4.000000   4.000000
# 50%    4.579552e+07   61781.000000      2020.0   4.000000   4.000000
# 75%    4.580487e+07   88438.000000      2020.0   4.000000  12.000000
# max    4.581615e+07  627220.000000      2020.0  12.000000  12.000000

# %%
b['Mileage'] = b['Mileage'].astype(int)
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_6376/3166205366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['Mileage'] = b['Mileage'].astype(int)

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 956 to 19180
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                47 non-null     int64
#  1   Price             47 non-null     int64
#  2   Levy              47 non-null     object
#  3   Manufacturer      47 non-null     object
#  4   Model             47 non-null     object
#  5   Prod. year        47 non-null     int64
#  6   Category          47 non-null     object
#  7   Leather interior  47 non-null     object
#  8   Fuel type         47 non-null     object
#  9   Engine volume     47 non-null     object
#  10  Mileage           47 non-null     int32
#  11  Cylinders         47 non-null     float64
#  12  Gear box type     47 non-null     object
#  13  Drive wheels      47 non-null     object
#  14  Doors             47 non-null     object
#  15  Wheel             47 non-null     object
# ...

# %%
b.describe()
# Out:
#                  ID          Price  Prod. year        Mileage  Cylinders  \
# count  4.700000e+01      47.000000        47.0      47.000000  47.000000
# mean   4.573359e+07   63006.106383      2020.0   10471.234043   4.489362
# std    2.280244e+05   91748.310488         0.0   18432.737780   1.516179
# min    4.467634e+07       3.000000      2020.0       0.000000   1.000000
# 25%    4.576476e+07   13642.000000      2020.0    1669.000000   4.000000
# 50%    4.579552e+07   61781.000000      2020.0    4654.000000   4.000000
# 75%    4.580487e+07   88438.000000      2020.0   13230.000000   4.000000
# max    4.581615e+07  627220.000000      2020.0  116000.000000  12.000000
#
#          Airbags
# count  47.000000
# mean    7.617021
# std     4.245474
# min     0.000000
# 25%     4.000000
# 50%     4.000000
# 75%    12.000000
# max    12.000000

# %%
x = b[['Mileage', 'Cylinders', 'Airbags']]
y = b[['Price']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (37, 3)
# (37, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
print(y_test)
print(y_predict)
# Out:
#        Price
# 956    12074
# 18491  31675
# 17779    300
# 9261   31675
# 7276       3
# 13037  48296
# 4049   31675
# 13513   7840
# 7529    7840
# 15245  96915
# [[   4582.21775001]
#  [ 203019.68959933]
#  [-184493.62800987]
#  [ 203019.68959933]
#  [ 907161.71067163]
#  [ 202997.63358245]
#  [ 203019.68959933]
#  [  62920.0986367 ]
#  [   4643.68706255]
#  [  77283.3567916 ]]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 184608.78780944768

# %%
mean_squared_error(y_test, y_predict)
# Out:
# 97258077659.37883

# %%
lr.intercept_
# Out:
# array([-283731.15888691])

# %%
lr.coef_
# Out:
# array([[ 3.50652097e-02,  9.92375309e+04, -9.06107172e+03]])

# %%
from sklearn.tree import DecisionTreeRegressor,

# %%
dr = DecisionTreeRegressor()

# %%
dr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict = dr.predict(x_test)

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 41217601081.3

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 87727.7

# %%
r2_score(y_test,y_predict)
# Out:
# -51.80498414321358

# %%
ca
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
ca['Engine volume'].str.split(' ').str[0]
# Out:
# 0        3.5
# 1          3
# 2        1.3
# 3        2.5
# 4        1.3
#         ...
# 19232    2.0
# 19233    2.4
# 19234      2
# 19235      2
# 19236    2.4
# Name: Engine volume, Length: 19237, dtype: object

# %%
ca.corr()
# Out:
#                   ID     Price  Prod. year  Cylinders   Airbags
# ID          1.000000 -0.000844    0.071352  -0.039319 -0.020527
# Price      -0.000844  1.000000    0.012982   0.007518 -0.012824
# Prod. year  0.071352  0.012982    1.000000  -0.096797  0.236969
# Cylinders  -0.039319  0.007518   -0.096797   1.000000  0.176868
# Airbags    -0.020527 -0.012824    0.236969   0.176868  1.000000

# %%
sns.heatmap(ca.corr(), annot=True)
# Out:
# <AxesSubplot:>
